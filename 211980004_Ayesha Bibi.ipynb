# %%
import pandas as pd
df = pd.read_csv("Dummy_Sales_Data_v1.csv")

# %%
df
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %%
df.head()
#By deafult it return the first 5 rows.
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %%
df.tail()
#By default it returns the last 5 rows.
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9994  2021-10-16             Home         Sofia                  20
# 9995  2021-10-03       Healthcare         Maria                  30
# 9996  2021-11-13           Office          Emma                  29
# 9997  2021-12-23          Fashion        Stella                  22
# 9998  2021-07-12    Entertainment       Anthony                  25
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 9994                 14.0            Kenya        H-555     444885
# ...

# %%
df.sample()
#Randomly selected row,column or both from a dataset.
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 4128  2493510000999924935        15             173  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 4128  2021-10-04    Entertainment         Pablo                  21
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 4128                 11.0               UK      ENT-101     444773

# %%
df.info()
#Returns a quick summary of DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   int64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   object
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 937.5+ KB

# %%
df.describe()
#Returns descriptive statistics about the data.
# Out:
#             OrderID     Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# count  9.999000e+03  9999.000000     9999.000000         9999.000000
# mean   3.020951e+18    50.739874      175.620662           27.571857
# std    1.167549e+18    29.005532       43.527995            4.610452
# min    1.010010e+18     1.000000      100.000000           20.000000
# 25%    2.010410e+18    26.000000      138.000000           24.000000
# 50%    3.002410e+18    51.000000      176.000000           28.000000
# 75%    4.024510e+18    76.000000      213.000000           32.000000
# max    5.049610e+18   100.000000      250.000000           35.000000
#
#        Delivery_Time(Days)      OrderCode
# count          9948.000000    9999.000000
# mean             17.518396  444682.917392
# std               4.609531     525.343171
# min              10.000000  443880.000000
# 25%              14.000000  444222.000000
# 50%              18.000000  444772.000000
# 75%              22.000000  445113.000000
# ...

# %%
df.query("Quantity > 90")
#By default returns a DataFrame containing the filtered rows.
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 16    2808810000999928088        96             115      Delivered
# 25    3063710000999930637       100             173  Not Delivered
# 33    3255510000999932555        96             202      Delivered
# 36    4273710000999942737        97             202        Shipped
# ...                   ...       ...             ...            ...
# 9942  4010710000999940107        93             209        Shipped
# 9946  3812710000999938127        93             227      Delivered
# 9967  3167110000999931671        99             233      Delivered
# 9985  1541410000999915414        92             230        Shipped
# 9990  4241810000999942418        94             211    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %%
df.query("Quantity < 90")
# By default returns a DataFrame containing the filtered rows.
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# 5     4934810000999949348        51             204  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 1     2021-10-03           Office         Pablo                  34
# ...

# %%
df.loc[101, 'Sales_Manager']
#returns the group of rows and columns identified by their labels or names.
# Out:
# 'Maria'

# %%
df['Sales_Manager'].unique()
#return the unique values from a series.
# Out:
# array(['Pablo', 'Kristen', 'Abdul', 'Stella', 'Emma', 'John', 'Jacob',
#        'Sofia', 'Maria', 'Anthony'], dtype=object)

# %%
df['Shipping_Address'].unique()
#return the unique values from a series.
# Out:
# array(['Singapore', 'UK', 'Kenya', 'USA', 'Germany', 'India', 'Italy',
#        'China'], dtype=object)

# %%
df.nunique()
#Returns the number of unique values for each column.
# Out:
# OrderID                8842
# Quantity                100
# UnitPrice(USD)          151
# Status                    4
# OrderDate               108
# Product_Category          5
# Sales_Manager            10
# Shipping_Cost(USD)       16
# Delivery_Time(Days)      16
# Shipping_Address          8
# Product_Code             30
# OrderCode               108
# dtype: int64

# %%
df.isnull()
#Returns a DataFrame object where all the values are replaced with a boolean value True for Null values & otherwise False.
# Out:
#       OrderID  Quantity  UnitPrice(USD)  Status  OrderDate  Product_Category  \
# 0       False     False           False   False      False             False
# 1       False     False           False   False      False             False
# 2       False     False           False   False      False             False
# 3       False     False           False   False      False             False
# 4       False     False           False   False      False             False
# ...       ...       ...             ...     ...        ...               ...
# 9994    False     False           False   False      False             False
# 9995    False     False           False   False      False             False
# 9996    False     False           False   False      False             False
# 9997    False     False           False   False      False             False
# 9998    False     False           False   False      False             False
#
# ...

# %%
df.fillna("Ayesha")
#returns a new DataFrame object unless the inplace parameter is set to True.
# Out:
#                   OrderID  Quantity  UnitPrice         Status   OrderDate  \
# 0     2951110000999929511        92        238  Not Delivered  2021-08-08
# 1     2181910000999921819        61        136  Not Delivered  2021-10-03
# 2     3239110000999932391        67        235  Not Delivered  2021-09-27
# 3     1112610000999911126        33        133    Not Shipped  2021-07-30
# 4     1548310000999915483        13        189  Not Delivered  2021-08-15
# ...                   ...       ...        ...            ...         ...
# 9994  2301610000999923016        75        201  Not Delivered  2021-10-16
# 9995  1847410000999918474        37        135        Shipped  2021-10-03
# 9996  2385710000999923857        81        207      Delivered  2021-11-13
# 9997  2281610000999922816        18        117        Shipped  2021-12-23
# 9998  1468010000999914680        53        229      Delivered  2021-07-12
#
#      Product_Category Sales_Manager  Shipping_Cost(USD) Delivery_Time(Days)  \
# ...

# %%
df.sort_values("UnitPrice(USD)")
# returns a sorted DataFrame.
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 6943  1599910000999915999        64             100        Shipped
# 4309  4902510000999949025        63             100  Not Delivered
# 1199  3042610000999930426        85             100      Delivered
# 9539  2017510000999920175        68             100        Shipped
# 2107  5032110000999950321         7             100        Shipped
# ...                   ...       ...             ...            ...
# 2209  1622010000999916220        21             250  Not Delivered
# 7653  1165010000999911650       100             250  Not Delivered
# 4066  3287110000999932871        89             250    Not Shipped
# 1799  3091110000999930911         5             250        Shipped
# 8923  2305310000999923053        82             250    Not Shipped
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 6943  2021-07-04          Fashion          John                  35
# ...

# %%
df.value_counts()
#Return a Series containing counts of unique values.
# Out:
# OrderID              Quantity  UnitPrice(USD)  Status         OrderDate   Product_Category  Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  Shipping_Address  Product_Code  OrderCode
# 1010010000999910100  10        101             Shipped        2021-10-16  Healthcare        Jacob          35                  14.0                 Germany           HC-188        444885       1
# 3691010000999936910  35        169             Not Delivered  2021-10-17  Office            Pablo          21                  21.0                 Kenya             O-630         444886       1
# 3687210000999936872  69        132             Not Shipped    2021-08-08  Office            Anthony        21                  12.0                 China             O-901         444116       1
# 3687510000999936875  75        169             Shipped        2021-07-04  Home              Jacob          23                  11.0                 India             H-203         443881       1
# ...

# %%
df.nlargest(10 , "Shipping_Cost(USD)")
#Return the first n rows ordered by columns in descending order.
# Out:
#                   OrderID  Quantity  UnitPrice         Status   OrderDate  \
# 23    3629310000999936293        78        155      Delivered  2021-12-02
# 32    1859110000999918591        22        155        Shipped  2021-08-14
# 56    3594610000999935946         1        196      Delivered  2021-11-11
# 108   2411010000999924110        17        235        Shipped  2021-11-01
# 129   1434010000999914340        70        201      Delivered  2021-09-13
# ...                   ...       ...        ...            ...         ...
# 1368  4007210000999940072        80        108        Shipped  2021-12-08
# 1376  1951610000999919516        73        165  Not Delivered  2021-10-26
# 1393  3008310000999930083        50        185        Shipped  2021-08-14
# 1395  1318110000999913181         3        200    Not Shipped  2021-10-26
# 1404  3249810000999932498        13        118  Not Delivered  2021-12-10
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %%
df.nsmallest(5, "Shipping_Cost(USD)")
#Return the first n rows ordered by columns in ascending order.
# Out:
#                 OrderID  Quantity  UnitPrice         Status   OrderDate  \
# 11  2596010000999925960        44        246      Delivered  2021-07-11
# 30  1408910000999914089         7        130      Delivered  2021-07-04
# 47  2097210000999920972        62        216      Delivered  2021-10-09
# 84  3736410000999937364        87        136    Not Shipped  2021-09-14
# 94  1314010000999913140        85        208  Not Delivered  2021-07-11
#
#    Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 11           Office        Stella                  20                 12.0
# 30       Healthcare         Sofia                  20                  NaN
# 47             Home          Emma                  20                 10.0
# 84           Office       Kristen                  20                 20.0
# 94             Home         Jacob                  20                 11.0
#
#    Shipping_Address Product_Code  OrderCode
# ...

# %%
df.nsmallest(5 , 'UnitPrice(USD)')
#Return the first n rows ordered by columns in ascending order.
# Out:
#                  OrderID  Quantity  UnitPrice(USD)       Status   OrderDate  \
# 150  4309810000999943098        41             100      Shipped  2021-07-11
# 332  4047410000999940474        89             100    Delivered  2021-07-29
# 536  3635510000999936355        40             100      Shipped  2021-12-26
# 756  1565810000999915658        70             100      Shipped  2021-12-23
# 758  1846210000999918462        84             100  Not Shipped  2021-12-10
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 150             Home         Maria                  26                 22.0
# 332           Office          Emma                  23                 20.0
# 536           Office         Pablo                  29                 21.0
# 756    Entertainment         Sofia                  23                 25.0
# 758          Fashion         Sofia                  28                 13.0
#
#     Shipping_Address Product_Code  OrderCode
# ...

# %%
df.copy()
#returns a copy of the DataFrame.By default, the copy is a "deep copy" meaning that any changes made in the original DataFrame will NOT be reflected in the copy.
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %%
df.rename(columns={'UnitPrice(USD)' : 'UnitPrice'} , inplace = True)
df
# returns true if the name is successfully changed. The function is allow you to change the row indexes, and the columns labels.
# Out:
#                   OrderID  Quantity  UnitPrice         Status   OrderDate  \
# 0     2951110000999929511        92        238  Not Delivered  2021-08-08
# 1     2181910000999921819        61        136  Not Delivered  2021-10-03
# 2     3239110000999932391        67        235  Not Delivered  2021-09-27
# 3     1112610000999911126        33        133    Not Shipped  2021-07-30
# 4     1548310000999915483        13        189  Not Delivered  2021-08-15
# ...                   ...       ...        ...            ...         ...
# 9994  2301610000999923016        75        201  Not Delivered  2021-10-16
# 9995  1847410000999918474        37        135        Shipped  2021-10-03
# 9996  2385710000999923857        81        207      Delivered  2021-11-13
# 9997  2281610000999922816        18        117        Shipped  2021-12-23
# 9998  1468010000999914680        53        229      Delivered  2021-07-12
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %%
df.where(df["Shipping_Cost(USD)"] <=25 , 0)
#replaces the values of the rows where the condition evaluates to False.
# Out:
#                   OrderID  Quantity  UnitPrice         Status   OrderDate  \
# 0     2951110000999929511        92        238  Not Delivered  2021-08-08
# 1                       0         0          0              0           0
# 2     3239110000999932391        67        235  Not Delivered  2021-09-27
# 3                       0         0          0              0           0
# 4     1548310000999915483        13        189  Not Delivered  2021-08-15
# ...                   ...       ...        ...            ...         ...
# 9994  2301610000999923016        75        201  Not Delivered  2021-10-16
# 9995                    0         0          0              0           0
# 9996                    0         0          0              0           0
# 9997  2281610000999922816        18        117        Shipped  2021-12-23
# 9998  1468010000999914680        53        229      Delivered  2021-07-12
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %%
df.drop(2 , axis = 0)
# It returns a new DataFrame with the specified rows removed.
# Out:
#                   OrderID  Quantity  UnitPrice         Status   OrderDate  \
# 0     2951110000999929511        92        238  Not Delivered  2021-08-08
# 1     2181910000999921819        61        136  Not Delivered  2021-10-03
# 3     1112610000999911126        33        133    Not Shipped  2021-07-30
# 4     1548310000999915483        13        189  Not Delivered  2021-08-15
# 5     4934810000999949348        51        204  Not Delivered  2021-11-13
# ...                   ...       ...        ...            ...         ...
# 9994  2301610000999923016        75        201  Not Delivered  2021-10-16
# 9995  1847410000999918474        37        135        Shipped  2021-10-03
# 9996  2385710000999923857        81        207      Delivered  2021-11-13
# 9997  2281610000999922816        18        117        Shipped  2021-12-23
# 9998  1468010000999914680        53        229      Delivered  2021-07-12
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %%
df.drop('Quantity' , axis = 1)
#It returns a new DataFrame with the specified columns removed.
# Out:
#                   OrderID  UnitPrice         Status   OrderDate  \
# 0     2951110000999929511        238  Not Delivered  2021-08-08
# 1     2181910000999921819        136  Not Delivered  2021-10-03
# 2     3239110000999932391        235  Not Delivered  2021-09-27
# 3     1112610000999911126        133    Not Shipped  2021-07-30
# 4     1548310000999915483        189  Not Delivered  2021-08-15
# ...                   ...        ...            ...         ...
# 9994  2301610000999923016        201  Not Delivered  2021-10-16
# 9995  1847410000999918474        135        Shipped  2021-10-03
# 9996  2385710000999923857        207      Delivered  2021-11-13
# 9997  2281610000999922816        117        Shipped  2021-12-23
# 9998  1468010000999914680        229      Delivered  2021-07-12
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0          Healthcare         Pablo                  21                 25.0
# ...

# %%
df.corr()
# finds the correlation of each column in a DataFrame.
# Out:
#                       OrderID  Quantity  UnitPrice  Shipping_Cost(USD)  \
# OrderID              1.000000  0.008028   0.000866           -0.002899
# Quantity             0.008028  1.000000  -0.007948           -0.008935
# UnitPrice            0.000866 -0.007948   1.000000           -0.002698
# Shipping_Cost(USD)  -0.002899 -0.008935  -0.002698            1.000000
# Delivery_Time(Days) -0.017483 -0.003023  -0.013938           -0.004026
# OrderCode            0.005441 -0.002827   0.015882            0.008126
#
#                      Delivery_Time(Days)  OrderCode
# OrderID                        -0.017483   0.005441
# Quantity                       -0.003023  -0.002827
# UnitPrice                      -0.013938   0.015882
# Shipping_Cost(USD)             -0.004026   0.008126
# Delivery_Time(Days)             1.000000   0.008851
# OrderCode                       0.008851   1.000000
